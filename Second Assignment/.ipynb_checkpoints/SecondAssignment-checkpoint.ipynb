# %% [markdown]
# # Course of Multiagent Systems for smart machining: Second Assignment
#
# Student: Daniele Trisotto
#
# Email: daniele.trisotto@studenti.unitn.it or daniele.trisotto@eciu.eu
#
# University of Trento

# %% [markdown]
# ## Assignment:
# - Open data from last week:
#     - Each student will analyze one operation
#     - Compare power of operations:
#     - Average per revolution:
#     - Min/Max per revolution:
#     - Profile of the power curve per revolution(during cutting)
#     - Energy in one revolution:
#         - Energy is the integral of the power.

# %% [markdown]
# ## Brief Summary of Data Processing Steps

# %% [markdown]
# ## Importing Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker

# File data CSV
filedataC = 'Dati/Session5A1B.csv'                   #cut
filedataNC= 'Dati/Session5A1A.csv'                   #nocut

# Reading csv
dfC = pd.read_csv(filedataC, skiprows=10)
#dfC = dfC.iloc[:, :-1]
dfC = dfC.apply(pd.to_numeric, errors='coerce')
dfC = dfC.dropna()
dfNC = pd.read_csv(filedataNC, skiprows=10)
#dfNC = dfNC.iloc[:, :-1]
dfNC = dfNC.apply(pd.to_numeric, errors='coerce')
dfNC = dfNC.dropna()

# %%
dfC.columns = ['time', 
               'prog_pos_x', 
               'meas_pos_x', 
               'power', 
               'prog_pos_y', 
               'meas_pos_y',
               'prog_pos_z', 
               'meas_pos_z']

dfNC.columns = ['time', 
               'prog_pos_x', 
               'meas_pos_x', 
               'power', 
               'prog_pos_y', 
               'meas_pos_y',
               'prog_pos_z', 
               'meas_pos_z']

# %% [markdown]
# ## Power visualization

# %%
plt.figure(figsize=(10,6))

# dfC
plt.scatter(dfC['time'], dfC['power'], label='Cut', color='blue', s=5) # s=20 dimensione punti

# dfNC
plt.scatter(dfNC['time'], dfNC['power'], label='No Cut', color='red', s=5)

# Labels
plt.xlabel('Time [s]')
plt.ylabel('Power [W]')
plt.title('PowerVSTime')
plt.legend()
plt.grid(True)

plt.show()
# Out:
# <div id='9c51e895-018b-4037-bf7d-deab183eb6b1'></div>

# %%
from mpl_toolkits.mplot3d import Axes3D  # necessario per il 3D

# Scegli il DataFrame
df = dfC  # oppure dfNC

# Crea figura e asse 3D
fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(111, projection='3d')

# Scatter 3D
ax.scatter(df['prog_pos_x'], df['prog_pos_y'], df['prog_pos_z'], c='blue', s=10, alpha=0.6)

# Etichette assi
ax.set_xlabel('X [mm]')
ax.set_ylabel('Y [mm]')
ax.set_zlabel('Z [mm]')
ax.set_title('Posizioni utensile 3D')

# Visualizzazione
plt.show()
# Out:
# <div id='c4281e8d-d3c1-45cf-b264-0491c63e6aa6'></div>

# %% [markdown]
# ## Machining Parameters:
#
# ` E_MI_PL("FR_SURF_D63_ALU","FORET5.5_CARB_FSI",1,0.1,2,400,2,13,0,90,
# -1,90,0.5,0,0,90,0,90,170,90,-70,90,70,1,0);*RO*
# `
#
# D = 63  #(mm)
# Vc = 150    #(m/min)
# N = Vc/(np.pi * D) * 1000

# %%
cols_to_convert = dfC150.columns.difference(['time'])  

# # Conversion in numeric format 
for df in [dfC150, dfNC150, dfC1200, dfNC1200]:
    for col in cols_to_convert:
        df[col] = pd.to_numeric(df[col], errors='coerce')
   
dfC150 = dfC150.dropna()
dfNC150 = dfNC150.dropna()
dfC1200 = dfC1200.dropna()
dfNC1200 = dfNC1200.dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 cols_to_convert = dfC150.columns.difference(['time'])
#       3 # # Conversion in numeric format
#       4 for df in [dfC150, dfNC150, dfC1200, dfNC1200]:
#
# NameError: name 'dfC150' is not defined

# %% [markdown]
# #### Programed Parameters:

# %%
ap=1  #mm
f=0.2 #mm/rev
Vc150=150 #m/min

# %% [markdown]
# ## Specific Cutting Pressure Calculation

# %% [markdown]
# ### Calculating Cutting Power

# %%
# find minimum difference in terms of length between two dataframes
n150 = min(len(dfC150), len(dfNC150))
n1200 = min(len(dfC1200), len(dfNC1200))

# Initializing a column of power difference
dfC150['power_diff']=0.0
dfC1200['power_diff']=0.0

# Calculating the power difference between cutting and non cutting
dfC150.loc[dfC150.index[:n150], 'power_diff'] = dfC150['power'].iloc[:n150].values - dfNC150['power'].iloc[:n150].values
dfC1200.loc[dfC1200.index[:n1200], 'power_diff'] = dfC1200['power'].iloc[:n1200].values - dfNC1200['power'].iloc[:n1200].values

#Filtering only machining positions less than 47 and exact machining X positions and Z positions between 0 and -40
dfC150_filtered = dfC150[(dfC150['prog_pos_x'] <= 47)&(np.isclose(dfC150['prog_pos_x'] % 1, 0.0))&(dfC150['prog_pos_z']<=0.0)&(dfC150['prog_pos_z']>=-40.0)].copy() 
dfC1200_filtered = dfC1200[(dfC1200['prog_pos_x'] <= 47)&(np.isclose(dfC1200['prog_pos_x'] % 1, 0.0))&(dfC1200['prog_pos_z']<=0.0)&(dfC1200['prog_pos_z']>=-40.0)].copy()

# %% [markdown]
# #### Cutting power for constant cutting speed

# %%
plt.figure(figsize=(10, 6))
plt.plot(dfC150_filtered['time'], dfC150_filtered['power_diff'], marker='o', linestyle='-')
plt.xlabel('Time')
plt.ylabel('Power Difference')
plt.title('Power Difference vs Time')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Cutting Power for constant spindle speed

# %%
plt.figure(figsize=(10, 6))
plt.plot(dfC1200_filtered['time'], dfC1200_filtered['power_diff'], marker='o', linestyle='-')
plt.xlabel('Time')
plt.ylabel('Power Difference')
plt.title('Power Difference vs Time')
plt.grid(True)
plt.show()

# %% [markdown]
# From the previous graphs we can see that there are some outliers, in the next section outliers are removed

# %% [markdown]
# ### Outliers Removing from Vc=150

# %%
from sklearn.cluster import DBSCAN
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
import pandas as pd

# Diameter List
prog_values = list(range(46, 23, -2))

# Subplot settings
n_cols = 3
n_rows = (len(prog_values) + n_cols - 1) // n_cols
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, n_rows*4))
axes = axes.flatten()

# new dataframe for saving clean data
df_150 = pd.DataFrame()

for i, prog in enumerate(prog_values):
    df_prog = dfC150_filtered[dfC150_filtered['prog_pos_x'] == prog]
    if df_prog.empty:
        continue
    
    # DBSCAN for time outliers
    time_values = df_prog['time'].values.reshape(-1, 1)
    db = DBSCAN(eps=2.0, min_samples=5)
    labels = db.fit_predict(time_values)
    
    label_counts = Counter(labels)
    if -1 in label_counts:
        del label_counts[-1]
    if not label_counts:
        continue
    
    main_cluster = label_counts.most_common(1)[0][0]
    df_cluster = df_prog[labels == main_cluster]
    
    # robust standard deviation for amplitude outliers filtering
    median_val = df_cluster['power_diff'].median()
    mad_val = np.median(np.abs(df_cluster['power_diff'] - median_val))
    robust_std = 1.4826 * mad_val
    df_cluster_clean = df_cluster[np.abs(df_cluster['power_diff'] - median_val) <= 3 * robust_std]
    
    # clean data saving
    df_150 = pd.concat([df_150, df_cluster_clean], ignore_index=True)
    
    # mean and standard deviation on clean data for plotting
    mean_val = df_cluster_clean['power_diff'].mean()
    std_val = df_cluster_clean['power_diff'].std()
    
    # plot
    ax = axes[i]
    ax.plot(df_cluster_clean['time'], df_cluster_clean['power_diff'], marker='o', linestyle='-', label='Power Diff')
    ax.axhline(mean_val, color='red', linestyle='--', label='Mean')
    ax.axhline(mean_val + std_val, color='green', linestyle='--', label='Mean + STD')
    ax.axhline(mean_val - std_val, color='green', linestyle='--', label='Mean - STD')
    
    ax.set_title(f'prog_pos_x = {prog}')
    ax.set_xlabel('Time')
    ax.set_ylabel('Power Difference')
    ax.grid(True)
    ax.legend()


for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Outliers Removing from N=1200

# %%
from sklearn.cluster import DBSCAN
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
import pandas as pd

# Diameter List
prog_values = list(range(46, 23, -2))

# Subplot settings
n_cols = 3
n_rows = (len(prog_values) + n_cols - 1) // n_cols
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, n_rows*4))
axes = axes.flatten()

# new dataframe for saving clean data
df_1200 = pd.DataFrame()

for i, prog in enumerate(prog_values):
    df_prog = dfC1200_filtered[dfC1200_filtered['prog_pos_x'] == prog]
    if df_prog.empty:
        continue
    
    # DBSCAN for time outliers
    time_values = df_prog['time'].values.reshape(-1, 1)
    db = DBSCAN(eps=2.0, min_samples=5)
    labels = db.fit_predict(time_values)
    
    label_counts = Counter(labels)
    if -1 in label_counts:
        del label_counts[-1]
    if not label_counts:
        continue
    
    main_cluster = label_counts.most_common(1)[0][0]
    df_cluster = df_prog[labels == main_cluster]
    
    # robust standard deviation for amplitude outliers filtering
    median_val = df_cluster['power_diff'].median()
    mad_val = np.median(np.abs(df_cluster['power_diff'] - median_val))
    robust_std = 1.4826 * mad_val
    df_cluster_clean = df_cluster[np.abs(df_cluster['power_diff'] - median_val) <= 1.5 * robust_std]
    
    # clean data saving
    df_1200 = pd.concat([df_1200, df_cluster_clean], ignore_index=True)
    
    # mean and standard deviation on clean data for plotting
    mean_val = df_cluster_clean['power_diff'].mean()
    std_val = df_cluster_clean['power_diff'].std()
    
    # plot
    ax = axes[i]
    ax.plot(df_cluster_clean['time'], df_cluster_clean['power_diff'], marker='o', linestyle='-', label='Power Diff')
    ax.axhline(mean_val, color='red', linestyle='--', label='Mean')
    ax.axhline(mean_val + std_val, color='green', linestyle='--', label='Mean + STD')
    ax.axhline(mean_val - std_val, color='green', linestyle='--', label='Mean - STD')
    
    ax.set_title(f'prog_pos_x = {prog}')
    ax.set_xlabel('Time')
    ax.set_ylabel('Power Difference')
    ax.grid(True)
    ax.legend()

for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### KC Calculation for Vc=150

# %%
# adding a column for Kc and calculating it 
df_150['Kc']=df_150['power_diff']*60/(Vc150*ap*f)

# calculating Kc max and min
df_Kc_summary150 = (
    df_150
    .groupby('prog_pos_x')['Kc']
    .agg(['min', 'max', 'mean']) 
    .reset_index() 
    .rename(columns={'min': 'Kc_min', 'max': 'Kc_max', 'mean' :'Kc_mean'})
)

df_Kc_summary150.iloc[::-1].style.set_caption("Summary of Kc values for Vc=150 m/min") \
    .format(precision=3) \
    .background_gradient(cmap="Blues") \
    .set_table_styles(
        [{"selector": "caption",
          "props": [("font-size", "16px"), ("font-weight", "bold"), ("text-align", "left")]}]
    )
# Out:
# <style type="text/css">
# #T_e14c3 caption {
#   font-size: 16px;
#   font-weight: bold;
#   text-align: left;
# }
# #T_e14c3_row0_col0, #T_e14c3_row3_col2, #T_e14c3_row6_col3, #T_e14c3_row10_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e14c3_row0_col1 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_e14c3_row0_col2 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_e14c3_row0_col3, #T_e14c3_row3_col3, #T_e14c3_row4_col0, #T_e14c3_row5_col2 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_e14c3_row1_col0 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_e14c3_row1_col1 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_e14c3_row1_col2 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_e14c3_row1_col3, #T_e14c3_row5_col1, #T_e14c3_row10_col2, #T_e14c3_row11_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_e14c3_row2_col0, #T_e14c3_row11_col3 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_e14c3_row2_col1 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_e14c3_row2_col2 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_e14c3_row2_col3, #T_e14c3_row4_col2 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_e14c3_row3_col0 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_e14c3_row3_col1, #T_e14c3_row9_col0 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_e14c3_row4_col1 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_e14c3_row4_col3 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_e14c3_row5_col0 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_e14c3_row5_col3 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_e14c3_row6_col0 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_e14c3_row6_col1 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_e14c3_row6_col2 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_e14c3_row7_col0 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_e14c3_row7_col1 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_e14c3_row7_col2 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_e14c3_row7_col3 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_e14c3_row8_col0 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_e14c3_row8_col1 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_e14c3_row8_col2 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_e14c3_row8_col3 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_e14c3_row9_col1, #T_e14c3_row9_col2 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_e14c3_row9_col3 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_e14c3_row10_col0 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_e14c3_row10_col3 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_e14c3_row11_col1 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_e14c3_row11_col2 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e14c3">
#   <caption>Summary of Kc values for Vc=150 m/min</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e14c3_level0_col0" class="col_heading level0 col0" >prog_pos_x</th>
#       <th id="T_e14c3_level0_col1" class="col_heading level0 col1" >Kc_min</th>
#       <th id="T_e14c3_level0_col2" class="col_heading level0 col2" >Kc_max</th>
#       <th id="T_e14c3_level0_col3" class="col_heading level0 col3" >Kc_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e14c3_level0_row0" class="row_heading level0 row0" >11</th>
#       <td id="T_e14c3_row0_col0" class="data row0 col0" >46.000</td>
#       <td id="T_e14c3_row0_col1" class="data row0 col1" >2543.402</td>
#       <td id="T_e14c3_row0_col2" class="data row0 col2" >3411.388</td>
#       <td id="T_e14c3_row0_col3" class="data row0 col3" >3002.742</td>
#     </tr>
#     <tr>
#       <th id="T_e14c3_level0_row1" class="row_heading level0 row1" >10</th>
#       <td id="T_e14c3_row1_col0" class="data row1 col0" >44.000</td>
#       <td id="T_e14c3_row1_col1" class="data row1 col1" >625.758</td>
#       <td id="T_e14c3_row1_col2" class="data row1 col2" >5329.033</td>
#       <td id="T_e14c3_row1_col3" class="data row1 col3" >2965.811</td>
#     </tr>
#     <tr>
#       <th id="T_e14c3_level0_row2" class="row_heading level0 row2" >9</th>
#       <td id="T_e14c3_row2_col0" class="data row2 col0" >42.000</td>
#       <td id="T_e14c3_row2_col1" class="data row2 col1" >1614.858</td>
#       <td id="T_e14c3_row2_col2" class="data row2 col2" >4239.003</td>
#       <td id="T_e14c3_row2_col3" class="data row2 col3" >2978.969</td>
#     </tr>
#     <tr>
#       <th id="T_e14c3_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_e14c3_row3_col0" class="data row3 col0" >40.000</td>
#       <td id="T_e14c3_row3_col1" class="data row3 col1" >545.015</td>
#       <td id="T_e14c3_row3_col2" class="data row3 col2" >5429.961</td>
#       <td id="T_e14c3_row3_col3" class="data row3 col3" >3002.782</td>
#     </tr>
#     <tr>
#       <th id="T_e14c3_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_e14c3_row4_col0" class="data row4 col0" >38.000</td>
#       <td id="T_e14c3_row4_col1" class="data row4 col1" >1796.530</td>
#       <td id="T_e14c3_row4_col2" class="data row4 col2" >3754.546</td>
#       <td id="T_e14c3_row4_col3" class="data row4 col3" >2993.466</td>
#     </tr>
#     <tr>
#       <th id="T_e14c3_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_e14c3_row5_col0" class="data row5 col0" >36.000</td>
#       <td id="T_e14c3_row5_col1" class="data row5 col1" >60.557</td>
#       <td id="T_e14c3_row5_col2" class="data row5 col2" >4642.718</td>
#       <td id="T_e14c3_row5_col3" class="data row5 col3" >3012.649</td>
#     </tr>
#     <tr>
#       <th id="T_e14c3_level0_row6" class="row_heading level0 row6" >5</th>
#       <td id="T_e14c3_row6_col0" class="data row6 col0" >34.000</td>
#       <td id="T_e14c3_row6_col1" class="data row6 col1" >1130.401</td>
#       <td id="T_e14c3_row6_col2" class="data row6 col2" >4965.689</td>
#       <td id="T_e14c3_row6_col3" class="data row6 col3" >3023.922</td>
#     </tr>
#     <tr>
#       <th id="T_e14c3_level0_row7" class="row_heading level0 row7" >4</th>
#       <td id="T_e14c3_row7_col0" class="data row7 col0" >32.000</td>
#       <td id="T_e14c3_row7_col1" class="data row7 col1" >2301.173</td>
#       <td id="T_e14c3_row7_col2" class="data row7 col2" >3693.988</td>
#       <td id="T_e14c3_row7_col3" class="data row7 col3" >2995.959</td>
#     </tr>
#     <tr>
#       <th id="T_e14c3_level0_row8" class="row_heading level0 row8" >3</th>
#       <td id="T_e14c3_row8_col0" class="data row8 col0" >30.000</td>
#       <td id="T_e14c3_row8_col1" class="data row8 col1" >746.872</td>
#       <td id="T_e14c3_row8_col2" class="data row8 col2" >3956.403</td>
#       <td id="T_e14c3_row8_col3" class="data row8 col3" >2985.671</td>
#     </tr>
#     <tr>
#       <th id="T_e14c3_level0_row9" class="row_heading level0 row9" >2</th>
#       <td id="T_e14c3_row9_col0" class="data row9 col0" >28.000</td>
#       <td id="T_e14c3_row9_col1" class="data row9 col1" >1534.115</td>
#       <td id="T_e14c3_row9_col2" class="data row9 col2" >4461.046</td>
#       <td id="T_e14c3_row9_col3" class="data row9 col3" >2999.498</td>
#     </tr>
#     <tr>
#       <th id="T_e14c3_level0_row10" class="row_heading level0 row10" >1</th>
#       <td id="T_e14c3_row10_col0" class="data row10 col0" >26.000</td>
#       <td id="T_e14c3_row10_col1" class="data row10 col1" >2725.073</td>
#       <td id="T_e14c3_row10_col2" class="data row10 col2" >3270.088</td>
#       <td id="T_e14c3_row10_col3" class="data row10 col3" >2990.548</td>
#     </tr>
#     <tr>
#       <th id="T_e14c3_level0_row11" class="row_heading level0 row11" >0</th>
#       <td id="T_e14c3_row11_col0" class="data row11 col0" >24.000</td>
#       <td id="T_e14c3_row11_col1" class="data row11 col1" >343.157</td>
#       <td id="T_e14c3_row11_col2" class="data row11 col2" >4824.389</td>
#       <td id="T_e14c3_row11_col3" class="data row11 col3" >3013.256</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Kc Calculation for N=1200

# %%
N = 1200  # rpm

# Vc calculation
df_1200['Vc_dia'] = np.pi * df_1200['prog_pos_x'] * N / 1000  # m/min

# Kc calculation
df_1200['Kc'] = df_1200['power_diff'] * 60 / (df_1200['Vc_dia'] * ap * f)
df_Kc_summary1200 = (
    df_1200
    .groupby('prog_pos_x')['Kc']
    .agg(['min', 'max', 'mean'])
    .reset_index()
    .rename(columns={'min': 'Kc_min', 'max': 'Kc_max', 'mean':'Kc_mean'})
)

df_Kc_summary1200.iloc[::-1].style.set_caption("Summary of Kc values for N=1200 rpm") \
    .format(precision=3) \
    .background_gradient(cmap="Blues") \
    .set_table_styles(
        [{"selector": "caption",
          "props": [("font-size", "16px"), ("font-weight", "bold"), ("text-align", "left")]}]
    )
# Out:
# <style type="text/css">
# #T_c1b01 caption {
#   font-size: 16px;
#   font-weight: bold;
#   text-align: left;
# }
# #T_c1b01_row0_col0, #T_c1b01_row0_col1, #T_c1b01_row11_col2, #T_c1b01_row11_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c1b01_row0_col2, #T_c1b01_row1_col3, #T_c1b01_row11_col0, #T_c1b01_row11_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_c1b01_row0_col3 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_c1b01_row1_col0 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_c1b01_row1_col1 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_c1b01_row1_col2 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_c1b01_row2_col0 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_c1b01_row2_col1 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_c1b01_row2_col2 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_c1b01_row2_col3 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_c1b01_row3_col0 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_c1b01_row3_col1 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_c1b01_row3_col2 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_c1b01_row3_col3 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_c1b01_row4_col0 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_c1b01_row4_col1 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_c1b01_row4_col2 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_c1b01_row4_col3 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_c1b01_row5_col0 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_c1b01_row5_col1 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_c1b01_row5_col2 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_c1b01_row5_col3 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_c1b01_row6_col0 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_c1b01_row6_col1, #T_c1b01_row9_col3 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_c1b01_row6_col2, #T_c1b01_row7_col2 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_c1b01_row6_col3 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_c1b01_row7_col0 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_c1b01_row7_col1 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_c1b01_row7_col3 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_c1b01_row8_col0 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_c1b01_row8_col1 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_c1b01_row8_col2 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_c1b01_row8_col3, #T_c1b01_row9_col2 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_c1b01_row9_col0 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_c1b01_row9_col1 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_c1b01_row10_col0 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_c1b01_row10_col1 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_c1b01_row10_col2 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_c1b01_row10_col3 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c1b01">
#   <caption>Summary of Kc values for N=1200 rpm</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1b01_level0_col0" class="col_heading level0 col0" >prog_pos_x</th>
#       <th id="T_c1b01_level0_col1" class="col_heading level0 col1" >Kc_min</th>
#       <th id="T_c1b01_level0_col2" class="col_heading level0 col2" >Kc_max</th>
#       <th id="T_c1b01_level0_col3" class="col_heading level0 col3" >Kc_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1b01_level0_row0" class="row_heading level0 row0" >11</th>
#       <td id="T_c1b01_row0_col0" class="data row0 col0" >46.000</td>
#       <td id="T_c1b01_row0_col1" class="data row0 col1" >1920.611</td>
#       <td id="T_c1b01_row0_col2" class="data row0 col2" >3806.302</td>
#       <td id="T_c1b01_row0_col3" class="data row0 col3" >3003.866</td>
#     </tr>
#     <tr>
#       <th id="T_c1b01_level0_row1" class="row_heading level0 row1" >10</th>
#       <td id="T_c1b01_row1_col0" class="data row1 col0" >44.000</td>
#       <td id="T_c1b01_row1_col1" class="data row1 col1" >1861.882</td>
#       <td id="T_c1b01_row1_col2" class="data row1 col2" >3869.793</td>
#       <td id="T_c1b01_row1_col3" class="data row1 col3" >3002.600</td>
#     </tr>
#     <tr>
#       <th id="T_c1b01_level0_row2" class="row_heading level0 row2" >9</th>
#       <td id="T_c1b01_row2_col0" class="data row2 col0" >42.000</td>
#       <td id="T_c1b01_row2_col1" class="data row2 col1" >1854.928</td>
#       <td id="T_c1b01_row2_col2" class="data row2 col2" >3977.577</td>
#       <td id="T_c1b01_row2_col3" class="data row2 col3" >3019.110</td>
#     </tr>
#     <tr>
#       <th id="T_c1b01_level0_row3" class="row_heading level0 row3" >8</th>
#       <td id="T_c1b01_row3_col0" class="data row3 col0" >40.000</td>
#       <td id="T_c1b01_row3_col1" class="data row3 col1" >1827.200</td>
#       <td id="T_c1b01_row3_col2" class="data row3 col2" >4136.298</td>
#       <td id="T_c1b01_row3_col3" class="data row3 col3" >3041.030</td>
#     </tr>
#     <tr>
#       <th id="T_c1b01_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_c1b01_row4_col0" class="data row4 col0" >38.000</td>
#       <td id="T_c1b01_row4_col1" class="data row4 col1" >1817.688</td>
#       <td id="T_c1b01_row4_col2" class="data row4 col2" >4206.046</td>
#       <td id="T_c1b01_row4_col3" class="data row4 col3" >3058.696</td>
#     </tr>
#     <tr>
#       <th id="T_c1b01_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_c1b01_row5_col0" class="data row5 col0" >36.000</td>
#       <td id="T_c1b01_row5_col1" class="data row5 col1" >1628.639</td>
#       <td id="T_c1b01_row5_col2" class="data row5 col2" >4305.855</td>
#       <td id="T_c1b01_row5_col3" class="data row5 col3" >3088.700</td>
#     </tr>
#     <tr>
#       <th id="T_c1b01_level0_row6" class="row_heading level0 row6" >5</th>
#       <td id="T_c1b01_row6_col0" class="data row6 col0" >34.000</td>
#       <td id="T_c1b01_row6_col1" class="data row6 col1" >1629.952</td>
#       <td id="T_c1b01_row6_col2" class="data row6 col2" >4393.783</td>
#       <td id="T_c1b01_row6_col3" class="data row6 col3" >3107.791</td>
#     </tr>
#     <tr>
#       <th id="T_c1b01_level0_row7" class="row_heading level0 row7" >4</th>
#       <td id="T_c1b01_row7_col0" class="data row7 col0" >32.000</td>
#       <td id="T_c1b01_row7_col1" class="data row7 col1" >1505.934</td>
#       <td id="T_c1b01_row7_col2" class="data row7 col2" >4392.307</td>
#       <td id="T_c1b01_row7_col3" class="data row7 col3" >3123.153</td>
#     </tr>
#     <tr>
#       <th id="T_c1b01_level0_row8" class="row_heading level0 row8" >3</th>
#       <td id="T_c1b01_row8_col0" class="data row8 col0" >30.000</td>
#       <td id="T_c1b01_row8_col1" class="data row8 col1" >1311.836</td>
#       <td id="T_c1b01_row8_col2" class="data row8 col2" >4390.633</td>
#       <td id="T_c1b01_row8_col3" class="data row8 col3" >3141.387</td>
#     </tr>
#     <tr>
#       <th id="T_c1b01_level0_row9" class="row_heading level0 row9" >2</th>
#       <td id="T_c1b01_row9_col0" class="data row9 col0" >28.000</td>
#       <td id="T_c1b01_row9_col1" class="data row9 col1" >1147.378</td>
#       <td id="T_c1b01_row9_col2" class="data row9 col2" >4474.775</td>
#       <td id="T_c1b01_row9_col3" class="data row9 col3" >3156.171</td>
#     </tr>
#     <tr>
#       <th id="T_c1b01_level0_row10" class="row_heading level0 row10" >1</th>
#       <td id="T_c1b01_row10_col0" class="data row10 col0" >26.000</td>
#       <td id="T_c1b01_row10_col1" class="data row10 col1" >895.838</td>
#       <td id="T_c1b01_row10_col2" class="data row10 col2" >4633.642</td>
#       <td id="T_c1b01_row10_col3" class="data row10 col3" >3175.260</td>
#     </tr>
#     <tr>
#       <th id="T_c1b01_level0_row11" class="row_heading level0 row11" >0</th>
#       <td id="T_c1b01_row11_col0" class="data row11 col0" >24.000</td>
#       <td id="T_c1b01_row11_col1" class="data row11 col1" >736.234</td>
#       <td id="T_c1b01_row11_col2" class="data row11 col2" >4785.523</td>
#       <td id="T_c1b01_
